# %% [markdown]
# # FBSP: Image processing - Neighbourhood processing
# #### Author: Nick Yao Larsen
# #### Email: nylarsen@cfin.au.dk
#
# In this tutorial, we'll look at how kernels can affect an image using convolution (blur, remove noice, detect edges)

# %% [markdown]
# ## Exercise 1
# 1. Load the image 'blood1_noisy.tif' (from Moodle)
# 2 Try three different filters on blood1_noisy: A median filter (size 5x5), a mean filter (size 5x5), a Gaussian filter (sigma = 0.5).
#     - Hints: You can get the filters at ```skimage.filters``` [link](https://scikit-image.org/docs/stable/api/skimage.filters.html)
#     - You need to specify the sigma for a gaussian filter,  which basically means the width of the gaussian filter
# 3. Plot the noisy image and all three results in one figure
#     - Explain which method is best for removing this type of noise.
#
# ## Exercise 2
# 1. Create custom kernels (horizontal and vertical sobel filters)
# 2. Convolute the kernels on the image 'sdc_toilet.tif' (from Moodle)
#     - Display the image
# 3. Combine the vertical and horizontal edges (derivatives)
#
# ## Exercise 3
# 1. Load the image ```coin``` from ```skimage.data``` module
# 2. Apply edge detection and display the image
# 3. Make images binary
# 4. Fill the holes of each coin with white pixels

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from skimage import io, filters
from scipy import ndimage
from scipy.signal import convolve2d

# %% [markdown]
# ### 1.1 Load the image
# Load the image ```blood1_noisy.tif```

# %%
## CODE HERE

# %% [markdown]
# ### 1.2 Apply filters on the image
# * Try three different filters on blood1_noisy: A median filter (size 5x5), a mean filter (size 5x5), a Gaussian filter (sigma = 0.5).
#     - Hints: You can get the filters at ```skimage.filters``` and ```skimage.morphology``` link for [filters](https://scikit-image.org/docs/stable/api/skimage.filters.html) & [morphology](https://scikit-image.org/docs/stable/api/skimage.morphology.html)

# %%
## CODE HERE

# %% [markdown]
# ### 1.3 Plot figures
# Plot the noisy image and all three results in one figure.
# - Explain which method is best for removing this type of noise.

# %%
## CODE HERE

# %% [markdown]
# ### 2.1 Create custom kernels and display
# 1. Create a Horizontal Sobel Filter and Vertical Sobel Filter
# 2. Display the kernels with their values of each pixel using the ```heatmap``` function inside of ```seaborn``` [Link](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %%
## CODE HERE

# %% [markdown]
# ### 2.2 Convolute the two kernels on the same image
# Apply the two filters using convolution on the image ```sdc_toilet.jpg```. You should use the following package ```scipy.signal.convolve2d``` [link](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.convolve2d.html)

# %%
## CODE HERE

# %% [markdown]
# ### 2.3 Display the gradient magnitude
# In order to display the gradient magnitude, we need to combine both the vertical and horizontal edges (derivatives) we can use the following equation:\
# $G= \sqrt{G_x^2+G_y^2} $
#
# For more information look at [link](https://www.adeveloperdiary.com/data-science/computer-vision/how-to-implement-sobel-edge-detection-using-python-from-scratch/)

# %%
## CODE HERE

# %% [markdown]
# ### 3.1 Load the image coins from ```skimage.data``` module

# %%
## CODE HERE

# %% [markdown]
# ### 3.2 Apply edge detection to the image and display images
# 1. Apply the sobal filter
#     - Hint look at ```skimage.filters```
# 2. Apply the canny filter
#     - Hint look at ```skimage.feature```
# 3. Display the images using with ```cmap="gray```

# %%
## CODE HERE

# %% [markdown]
# ### 3.3 Make images binary
# 1. Check the datatype of ```img_canny```
#     - Why dont we need to do thresholding on the canny image?
# 2. Apply threshold on sobel image
#     - Visualize the image
# 3. Invert the Sobel image (black becomes background and white becomes edges)
#     - Hint use ```skimage.util``` to see how to invert an image
# 4. Display the inverted sobel image and the canny image next to each other

# %%
# 1. Check datatype of the canny filter
## CODE HERE

# %%
# Out:
# dtype('bool')

# %%
## CODE HERE
# 2. Find the Otsu threshold Sobel image and apply it

# %% [markdown]
# 3.3.3 invert the binary image
# Hint look at ```invert``` in [skimage.util](https://scikit-image.org/docs/stable/api/skimage.util.html)

# %%
# 3. Invert the binary image

# %%
## CODE HERE
# 4. Plot the binary solbel and canny filter

# %% [markdown]
# ### 3.4 Fill the holes of each coin with white pixels
# Fill the binary holes in the Sobel and Canny edge detection image
# * Hint look at the ```scipy.ndimage``` [link](https://docs.scipy.org/doc/scipy/reference/ndimage.html)
# * Why do you think that all the coins are not completely filled to become white?

# %%
## CODE HERE
# 5. Fill holes in the Sobel and Canny edge detection image

# %% [markdown]
# ### Optional
# if you are interested you can try to use the ```watershed segmentation``` to make the coins white

# %%
## CODE HERE (OPTIONAL)
